# %%
from IPython.display import HTML, display

def set_css():
  display(HTML('''
  <style>
    pre {
        white-space: pre-wrap;
    }
  </style>
  '''))
get_ipython().events.register('pre_run_cell', set_css)

# %%
# !pip install transformers einops accelerate langchain bitsandbytes
# !pip install sentence_transformers #Embedding
# !pip install llama_index
# !pip install llama-index-embeddings-langchain
# !pip install llama-index-llms-huggingface
# !pip install docx2txt
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.2/43.2 kB 1.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 314.1/314.1 kB 5.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 987.6/987.6 kB 8.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 119.8/119.8 MB 3.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 366.5/366.5 kB 24.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 kB 8.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 141.1/141.1 kB 8.6 MB/s eta 0:00:00
# ...
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# ...
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# ...
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# ...

# %%
# !pip install llama-index-embeddings-huggingface
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 853.2/853.2 kB 6.3 MB/s eta 0:00:00
# ...

# %%
from llama_index.core import VectorStoreIndex, SimpleDirectoryReader, ServiceContext  #Vector store index is for indexing the vector
from llama_index.llms.huggingface import HuggingFaceLLM
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
# /usr/local/lib/python3.10/dist-packages/pydantic/_internal/_fields.py:161: UserWarning: Field "model_id" has conflict with protected namespace "model_".
#
# You may be able to resolve this warning by setting `model_config['protected_namespaces'] = ()`.
#   warnings.warn(

# %%
system_prompt="""
Provide summary of the following retrieved documents for the user query.
Query: <query here>
Documents: <in-domain passages here>
Answer:
"""
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>

# %%
#huggin face token
#

# %%
# !huggingface-cli login
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#     _|    _|  _|    _|    _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|_|_|_|    _|_|      _|_|_|  _|_|_|_|
#     _|    _|  _|    _|  _|        _|          _|    _|_|    _|  _|            _|        _|    _|  _|        _|
#     _|_|_|_|  _|    _|  _|  _|_|  _|  _|_|    _|    _|  _|  _|  _|  _|_|      _|_|_|    _|_|_|_|  _|        _|_|_|
#     _|    _|  _|    _|  _|    _|  _|    _|    _|    _|    _|_|  _|    _|      _|        _|    _|  _|        _|
#     _|    _|    _|_|      _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|        _|    _|    _|_|_|  _|_|_|_|
#
#     To login, `huggingface_hub` requires a token generated from https://huggingface.co/settings/tokens .
# Enter your token (input will not be visible):
# Add token as git credential? (Y/n) n
# Token is valid (permission: read).
# Your token has been saved to /root/.cache/huggingface/token
# Login successful

# %%
import torch

llm = HuggingFaceLLM(
    context_window=4096,
    max_new_tokens=1024,
    generate_kwargs={"temperature": 0.0, "do_sample": False},
    system_prompt=system_prompt,
    tokenizer_name="meta-llama/Llama-2-7b-chat-hf",
    model_name="meta-llama/Llama-2-7b-chat-hf",
    device_map="auto",
    # loading model in 8bit for reducing memory
    model_kwargs={"torch_dtype": torch.float16 , "load_in_8bit":True}
)
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/614 [00:00<?, ?B/s]
# The `load_in_4bit` and `load_in_8bit` arguments are deprecated and will be removed in the future versions. Please, pass a `BitsAndBytesConfig` object in `quantization_config` argument instead.
# model.safetensors.index.json:   0%|          | 0.00/26.8k [00:00<?, ?B/s]
# ...

# %%
from llama_index.embeddings.huggingface import HuggingFaceEmbedding
from llama_index.core import Settings

embed_model = HuggingFaceEmbedding(
    # model_name="sentence-transformers/all-mpnet-base-v2"
    model_name="sentence-transformers/all-mpnet-base-v2"
)
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/10.6k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# config.json:   0%|          | 0.00/571 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/438M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/363 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# ...

# %%
import os
data_path = '/content/drive/MyDrive/Colab Notebooks/Vaccine Hesitancy/dataset/News'

def get_data():
  my_docs = []

  for current, subfolder, files in os.walk(data_path):
    for file in files:
      temp_path = current + '/' + file
      my_docs.append(temp_path)

  return my_docs
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>

# %%
PERSIST_DIR = '/content/drive/MyDrive/Colab Notebooks/Lab - LLM/Index_Storage_Folder_News_LLama-2/'
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>

# %%
import os.path
from llama_index.core import Document
from llama_index.core.retrievers import VectorIndexRetriever
from llama_index.core import StorageContext, load_index_from_storage
from llama_index.core.indices.postprocessor import SimilarityPostprocessor
from llama_index.core.query_engine import RetrieverQueryEngine

service_context=ServiceContext.from_defaults(
    chunk_size=256,
    llm=llm,
    embed_model=embed_model
)

if not os.path.exists(PERSIST_DIR):
  my_docs = get_data()
  documents = SimpleDirectoryReader(input_files=my_docs).load_data()
  index=VectorStoreIndex.from_documents(documents,service_context=service_context)
  index.storage_context.persist(persist_dir=PERSIST_DIR)
else:
  storage_contex = StorageContext.from_defaults(persist_dir=PERSIST_DIR)
  index = load_index_from_storage(storage_context=storage_contex,service_context=service_context)

retriever = VectorIndexRetriever(index=index, similarity_top_k=10)
#takes set of nodes and applies some kind of transformation, filter nodes below 0.80 similarity score
postprocessor = SimilarityPostprocessor(similarity_cutoff=0.6)
query_engine = RetrieverQueryEngine(retriever=retriever, node_postprocessors=[postprocessor])

# query_engine=index.as_query_engine()
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
# <ipython-input-10-21012b2956a3>:8: DeprecationWarning: Call to deprecated class method from_defaults. (ServiceContext is deprecated, please use `llama_index.settings.Settings` instead.) -- Deprecated since version 0.10.0.
#   service_context=ServiceContext.from_defaults(

# %%
#on avg it takes 50s to 1 min to generate response
response=query_engine.query("What is people's attitude towards vaccine?")
print(response)
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
# /usr/local/lib/python3.10/dist-packages/transformers/generation/configuration_utils.py:515: UserWarning: `do_sample` is set to `False`. However, `temperature` is set to `0.0` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `temperature`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/transformers/generation/configuration_utils.py:520: UserWarning: `do_sample` is set to `False`. However, `top_p` is set to `0.9` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `top_p`.
#   warnings.warn(
# This is a friendly reminder - the current text generation call will exceed the model's predefined maximum length (4096). Depending on the model, you may observe exceptions, performance degradation, or nothing at all.
# ...

# %%
for node in response.source_nodes:
  print(node)
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
# Node ID: 8ede0953-3166-4167-ae39-679bfa7c62d4
# Text: And that was just absolutely interrupted this year. That is why
# I am most grateful for the vaccine. Casey Grove: Theres still going to
# be people that are skeptical. I wonder what would you say to somebody
# whos really skeptical of getting this vaccine for their kid and maybe
# even leaning towards not doing it? What would you tell that person?
# Dr. ...
# Score:  0.677
#
# Node ID: 6d99e760-f127-4768-89a9-b21bb37910f1
# Text: And there have been thousands of children hospitalized. But not
# all parents are so eager to vaccinate their kids. The Kaiser Family
# Foundation recently released a survey showing fewer than a third of
# parents say they plan to get their kids COVID-19 shots as soon as its
# possible. Another 32% said they would wait and see. Reluctance,
# especially ea...
# Score:  0.677
#
# Node ID: 430799c9-7c06-4655-ba4c-399e9326f7f6
# ...

# %%
response=query_engine.query("How people's attitude towards covid-19 vaccine changed considering the timeline from 2020 to 2022?")
print(response)
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-16-3e55ca7626b6> in <cell line: 1>()
# ----> 1 response=query_engine.query("How people's attitude towards covid-19 vaccine changed considering the timeline from 2020 to 2022?")
#       2 print(response)
#
# /usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/dispatcher.py in wrapper(func, instance, args, kwargs)
#     228             )
#     229             try:
# --> 230                 result = func(*args, **kwargs)
#     231             except BaseException as e:
#     232                 self.event(SpanDropEvent(span_id=id_, err_str=str(e)))
#
# /usr/local/lib/python3.10/dist-packages/llama_index/core/base/base_query_engine.py in query(self, str_or_query_bundle)
# ...

# %%
for node in response.source_nodes:
  print(node)

# %%
response=query_engine.query("Top 5 reasons for covid-19 vaccine hesitancy?")
print(response)
print("\n\n")
for node in response.source_nodes:
  print(node)

# %%
response=query_engine.query("What are some of the measures that improved people's confidence in vaccine hesitancy?")
print(response)

print("\n\n")

for node in response.source_nodes:
  print(node)

# %%
response=query_engine.query("What is the top most reason for vaccine hesitancy?")
print(response)

print("\n\n")

for node in response.source_nodes:
  print(node)

# %%
response=query_engine.query("Does people's confidence in vaccine hesitancy depend on their demographic?")
print(response)

print("\n\n")

for node in response.source_nodes:
  print(node)

# %%
response=query_engine.query("People from which part of the world are mostly hesitant about towards covid-19 vaccine and people from which part are mostly confident in it?")
print(response)

print("\n\n")

for node in response.source_nodes:
  print(node)

# %%
response=query_engine.query("Which covid-19 vaccine variant do people prefer the most?")
print(response)

# %%
response=query_engine.query("Which people prefer between Pfizer and Moderna?")
print(response)

print("\n")

for node in response.source_nodes:
  print(node)

# %%
response=query_engine.query("Which country is more susceptible to covid-19?")
print(response)

print("\n")

for node in response.source_nodes:
  print(node)

# %% [markdown]
# ### Minority Question

# %%
response=query_engine.query("Vaccine situation among the religious minorities in Alaska?")
print(response)

print("\n")

for node in response.source_nodes:
  print(node)
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
# /usr/local/lib/python3.10/dist-packages/transformers/generation/configuration_utils.py:515: UserWarning: `do_sample` is set to `False`. However, `temperature` is set to `0.0` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `temperature`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/transformers/generation/configuration_utils.py:520: UserWarning: `do_sample` is set to `False`. However, `top_p` is set to `0.9` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `top_p`.
#   warnings.warn(
# ...

# %%
response=query_engine.query("Are Russian Orthodox Christian in Alaska anti-vaccine, pro-vaccine, or neutral?")
print(response)

print("\n")

for node in response.source_nodes:
  print(node)
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
# /usr/local/lib/python3.10/dist-packages/transformers/generation/configuration_utils.py:515: UserWarning: `do_sample` is set to `False`. However, `temperature` is set to `0.0` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `temperature`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/transformers/generation/configuration_utils.py:520: UserWarning: `do_sample` is set to `False`. However, `top_p` is set to `0.9` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `top_p`.
#   warnings.warn(
# ...

# %%
response=query_engine.query("Are Jewish community in Alaska anti-vaccine, pro-vaccine, or neutral?")
print(response)

print("\n")

for node in response.source_nodes:
  print(node)
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
# The state of Alaska is trying to increase vaccine hesitancy and refusal rates among underserved populations, including seniors, by educating them about the vaccine and encouraging them to get vaccinated. The state health department is coordinating with health care providers to give local presentations and is sending postcards to underserved communities to encourage them to make an appointment. Just two-thirds of Alaskans age 65 and up are fully vaccinated so far, and the state recently sent about 3,500 postcards to encourage non-vaccinated seniors to get vaccinated. The state also wants to increase vaccination among older Alaskans, who are most at risk of becoming seriously ill from the coronavirus.
#
#
# Node ID: d2265ec8-f96c-417c-b01e-ccd824f8c63b
# Text: Even before the Alaska-specific survey was finished, Larkin, the
# pollster, said his firm stopped asking a question about whether
# ...

# %%
response=query_engine.query("Are Native Alaskan anti-vaccine, pro-vaccine, or neutral?")
print(response)

print("\n")

for node in response.source_nodes:
  print(node)
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
# ...

# %%
response=query_engine.query("Is White community in Alaska anti-vaccine, pro-vaccine, or neutral?")
print(response)

print("\n")

for node in response.source_nodes:
  print(node)
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
# The White community in Alaska is neutral or pro-vaccine. While there is no direct evidence to suggest that the White community is anti-vaccine, the context information provides information on vaccination rates among different racial and ethnic groups in Alaska, which suggests that there may be variations in vaccine acceptance and uptake among different groups. The context information highlights the challenges faced in rural Alaska, where access to vaccines can be limited, which may contribute to lower vaccination rates in some areas. However, there is no evidence to suggest that the White community is particularly anti-vaccine or resistant to vaccination.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ...

# %%
response=query_engine.query("Is Latino community in Alaska anti-vaccine, pro-vaccine, or neutral?")
print(response)

print("\n")

for node in response.source_nodes:
  print(node)
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
# ...

# %%
response=query_engine.query("Is American Indian in Alaska anti-vaccine, pro-vaccine, or neutral?")
print(response)

print("\n")

for node in response.source_nodes:
  print(node)
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
# American Indians in Alaska are supportive of COVID-19 vaccination efforts, as evidenced by the fact that tribal health-care leaders are working with the Trump administration to distribute vaccines to rural and Indigenous Alaskans. Additionally, tribal providers are prioritizing vaccination efforts in their communities, expanding the availability of doses beyond senior citizens. While some have raised concerns about the prioritization of vaccinations for younger, healthy people whose jobs don't place them at high risk of catching COVID-19, the foundation is still focused on Native elders and prioritizing same-day access for those who might not have been willing to get the shot when it was first available. Overall, American Indians in Alaska are supportive of vaccination efforts and are working to prioritize vaccination in their communities.
#
# ...

# %%
response=query_engine.query("Which religious minorities in Alaska are hesitant toward COVID vaccine?")
print(response)

print("\n")

for node in response.source_nodes:
  print(node)
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
# ...
